# %% [markdown]
# # Page 2
# [Yara link](http://www.arte.tv/guide/es/060139-016-A/el-rev%C3%A9s-de-los-mapas-noticias-de-la-ant%C3%A1rtida?country=DE)
# ![](pic.jpg)
# <iframe width="100%" height="700" src="//jsfiddle.net/YaraBJ/nmafo5r7/embedded/result/" allowfullscreen="allowfullscreen" frameborder="0"></iframe>

# %% [markdown]
# # Wearables Report
#
# ### CI First Update !
#
# ![](http://cache.lego.com/r/catalogs/-/media/catalogs/videos/disney%20princess/2015/mini%20movies/picture_perfect1488x842.jpg?l.r2=-477756477)

# %% [markdown]
# Im a sub slide

# %% [markdown]
# # i am not a sub slide

# %%
from IPython.display import HTML
HTML(''' <iframe width="100%" height="500" src="//jsfiddle.net/YaraBJ/yar4nyLs/embedded/result/" allowfullscreen="allowfullscreen" frameborder="0"></iframe>''')
# Out:
#  <iframe width="100%" height="500" src="//jsfiddle.net/YaraBJ/yar4nyLs/embedded/result/" allowfullscreen="allowfullscreen" frameborder="0"></iframe>

# %% [markdown]
# <iframe width="100%" height="300" src="//jsfiddle.net/YaraBJ/yar4nyLs/embedded/result/" allowfullscreen="allowfullscreen" frameborder="0"></iframe>

# %% [markdown]
# <html>
# <head>
#   <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#   <meta name="robots" content="noindex, nofollow">
#   <meta name="googlebot" content="noindex, nofollow">
#   <script type="text/javascript" src="//d3js.org/d3.v3.js"></script>
#
#
#
#
#
#
#
#
#     <link rel="stylesheet" type="text/css" href="/css/result-light.css">
#
#
#
#
#   <style type="text/css">
#     .donut {
#   font-family: "Helvetica";
#   font-size: 14px;
#   width: 900px;
#   height: 400px;
#   position: absolute;
#   top: 60px;
#   left: 100px;
# }
#
# .title {
#   position: absolute;
#   left: 240px;
#   font-size: 26px;
# }
#
# .form {
#   position: absolute;
#   left: 120px;
#   top: 390px;
#   font-family: "Helvetica";
#   font-size: 14px;
# }
#
# svg.labels text {
#   color: #fff;
# }
#
# .legend {
#   font-size: 11px;
#   width: 100px;
# }
#
# rect {
#   stroke-width: 30px;
#   width: 300px;
# }
#
# svg {
#   width: 800px;
#   height: 500px;
#   left: 0px;
# }
#
# path.slice {
#   stroke-width: 3px;
# }
#
# polyline {
#   opacity: .3;
#   stroke: #F00;
#   stroke-width: 2px;
#   fill: none;
# }
#
#   </style>
#
#   <title>Final donut d3js by YaraBJ</title>
#
#
#
#
#
#
#
# <script type='text/javascript'>//<![CDATA[
# window.onload=function(){
# var svg = d3.select("div.donut")
# 	.append("svg")
# 	.append("g")
# svg.append("g")
# 	.attr("class", "slices");
# svg.append("g")
# 	.attr("class", "labels");
# svg.append("g")
# 	.attr("class", "lines");
# svg.append("g")
# 	.attr("class", "skills");
#
#
#
# var width = 400,
#   height = 300,
#   radius = Math.min(width, height) / 2;
# pcenter = width - radius;
#
# var pie = d3.layout.pie()
# 	.sort(null)
# 	.value(function(d) {
# 		return d.value;
# 	});
# var legendRectSize = 18;
# var legendSpacing = 4;
#
# var arc = d3.svg.arc()
# 	.outerRadius(radius * 0.8)
# 	.innerRadius(radius * 0.6);
#
# var outerArc = d3.svg.arc()
# 	.innerRadius(radius * 0.9)
# 	.outerRadius(radius * 0.9);
#
# svg.attr("transform", "translate(" + width / 1.5 + "," + height / 2 + ")");
#
# var key = function(d){ return d.data.label; };
#
# var color = d3.scale.ordinal()
#   .range(["#c5ccdd", "#cea7a6", "#eaeaea", "#a3a3a3"]);
#
# var matrix = [
#   [{label: 'firm1',    value: 20,    skil: '2012'},
#    {label: 'firm2',    value: 30,    skil: '2012'},
#    {label: 'firm3',    value: 40,    skil: '2012'},
#    {label: 'firm4',    value: 10,    skil: '2012'},
#    ],
#   [{label: 'firm1',    value: 45,    skil: '2013'},
#    {label: 'firm2',    value: 25,    skil: '2013'},
#    {label: 'firm3',    value: 20,    skil: '2013'},
#    {label: 'firm4',    value: 10,    skil: '2013'},
#    ],
#   [{label: 'firm1',    value: 50,    skil: '2014'},
#    {label: 'firm2',    value: 30,    skil: '2014'},
#    {label: 'firm3',    value: 15,    skil: '2014'},
#    {label: 'firm4',    value: 5,     skil: '2014'},
#    ],
#   [{label: 'firm1',    value: 70,    skil: '2015'},
#    {label: 'firm2',    value: 15,    skil: '2015'},
#    {label: 'firm3',    value: 10,    skil: '2015'},
#    {label: 'firm4',    value: 5,     skil: '2015'},
#    ]
# ];
#
# function arrayData (num){
#     var ar = matrix;
#     return ar[num];
# }
#
#  var a=0;
#
#  var timerId = setInterval(function() {
#
# var rad = document.myForm.myRadios;
# var prev = null;
# for (var i = 0; i < rad.length; i++) {
#   rad[i].onclick = function() {
#     a = this.value
#   };
# }
#   var test = arrayData(a);
#   change(test);
# }, 1000);
#
#
#
# function change(data) {
#
# 	/* ------- PIE SLICES -------*/
# 	var slice = svg.select(".slices").selectAll("path.slice")
# 		.data(pie(data), key);
#
#
# 	slice.enter()
# 		.insert("path")
# 		.style("fill", function(d) { return color(d.data.label); })
# 		.attr("class", "slice", "value");
#
#
# 	slice
# 		.transition().ease("elastic").duration(1000)
#             .each("end", function(d,i){
#                 d3.selectAll('.skills text').text(function(d,i){return d.data.skil;});
#                 d3.selectAll('.labels text').text(function(d) {return d.data.label+": "+ (((d.endAngle - d.startAngle) / (2 * Math.PI)) * 100).toFixed(1) + '%';});
#
#             })
#             .attrTween("d", function(d) {
# 			this._current = this._current || d;
# 			var interpolate = d3.interpolate(this._current, d);
# 			this._current = interpolate(0);
# 			return function(t) {
# 				return arc(interpolate(t));
# 			};
# 		})
# 	slice.exit()
# 		.remove();
#
#
#
#      /*---------SKILL ------------*/
#
# 	/* ------- TEXT LABELS -------*/
#
# 	var text = svg.select(".labels").selectAll("text")
# 		.data(pie(data), key);
#
# 	text.enter()
# 		.append("text")
# 		.attr("dy", ".35em")
#          .attr("fill", "black")
#     .text(function(d) {return d.data.label+" : "+ (((d.endAngle - d.startAngle) / (2 * Math.PI)) * 100).toFixed(1) + '%';})
#
# 	function midAngle(d){
# 		return d.startAngle + (d.endAngle - d.startAngle)/2;
# 	}
#
# 	text.transition().duration(1000)
# 		.attrTween("transform", function(d) {
# 			this._current = this._current || d;
# 			var interpolate = d3.interpolate(this._current, d);
# 			this._current = interpolate(0);
# 			return function(t) {
# 				var d2 = interpolate(t);
# 				var pos = outerArc.centroid(d2);
# 				pos[0] = radius * (midAngle(d2) < Math.PI ? 1 : -1);
# 				return "translate("+ pos +")";
# 			};
# 		})
# 		.styleTween("text-anchor", function(d){
# 			this._current = this._current || d;
# 			var interpolate = d3.interpolate(this._current, d);
# 			this._current = interpolate(0);
# 			return function(t) {
# 				var d2 = interpolate(t);
#             return midAngle(d2) < Math.PI ? "start":"end";
#          };
# 		});
#
# 	text.exit()
# 		.remove();
#
# 	/* ------- SLICE TO TEXT POLYLINES -------*/
#
# 	var polyline = svg.select(".lines").selectAll("polyline")
# 		.data(pie(data), key);
#
# 	polyline.enter()
# 		.append("polyline");
#
# 	polyline.transition().duration(1000)
# 		.attrTween("points", function(d){
# 			this._current = this._current || d;
# 			var interpolate = d3.interpolate(this._current, d);
# 			this._current = interpolate(0);
# 			return function(t) {
# 				var d2 = interpolate(t);
# 				var pos = outerArc.centroid(d2);
# 				pos[0] = radius * 0.95 * (midAngle(d2) < Math.PI ? 1 : -1);
# 				return [arc.centroid(d2), outerArc.centroid(d2), pos];
# 			};
# 		});
#
# 	polyline.exit()
# 		.remove();
# };
#
# }//]]>
#
# </script>
#
#
# </head>
#
# <body>
#   <div class="title"> Country i </div>
#
# <div class="donut"> </div>
#
# <form name="myForm" class="form">
# <label><input type="radio" name="myRadios" value="0" checked="checked">
# Year 2012</label>
# <label><input type="radio" name="myRadios" value="1">Year 2013</label>
# <label><input type="radio" name="myRadios" value="2">Year 2014</label>
# <label><input type="radio" name="myRadios" value="3">Year 2015</label>
# </form>
#
#
# </body>
#
# </html>
